# %%
import pandas as pd

# %%
rivers=['Ganga','Mississipi','Nile','Kaveri','Yamuna']

# %%
ser_rivers=pd.Series(rivers, index= ('r1','r2','r3','r4','r5'))

# %%
ser_rivers
# Out:
# r1         Ganga
# r2    Mississipi
# r3          Nile
# r4        Kaveri
# r5        Yamuna
# dtype: object

# %%
d={'ename':'aaa','eid':111,'esal':10000}
ser_emp= pd.Series(d)
ser_emp
# Out:
# ename      aaa
# eid        111
# esal     10000
# dtype: object

# %%
country=['uk','us','japan','india']
capital=['london','w.dc','tokyo','delhi']

ser_country_capital=pd.Series(capital,index=country)

# %%
emp_info={'ename':['john','miller','david','lin','richa'],
         'eid':[1,2,3,4,5],
         'esal':[111,222,333,4444,555]}

# %%
df=pd.DataFrame(emp_info,index=range(1,6))

# %%
df
# Out:
#     ename  eid  esal
# 1    john    1   111
# 2  miller    2   222
# 3   david    3   333
# 4     lin    4  4444
# 5   richa    5   555

# %%
df=pd.read_csv('Datasets/ted_data.csv')
df
# Out:
#                            speaker_name  \
# 0                          Alex Gendler
# 1                           Shari Davis
# 2                      Nita Mosby Tyler
# 3                          Susan Lupack
# 4                         Ariel Waldman
# ...                                 ...
# 2155                       Nancy Frates
# 2156                      Will Marshall
# 2157                        David Grady
# 2158  Vincent Moon and Naná Vasconcelos
# 2159                       Alex Gendler
#
#                                                   title posted_date duration  \
# 0              The Egyptian myth of the death of Osiris    Jul 2020     3:56
# 1     What if you could help decide how the governme...    Jul 2020    10:28
# 2           Want a more just world? Be an unlikely ally    Jul 2020    10:15
# 3              The race to decode a mysterious language    Jul 2020     4:24
# 4     The colorful critter world of microbes in Anta...    Jul 2020     5:56
# ...

# %%
df.shape
# Out:
# (2160, 9)

# %%
df.size
# Out:
# 19440

# %%
df.head(10)   #top 10 values will be printed
# Out:
#          speaker_name                                              title  \
# 0        Alex Gendler           The Egyptian myth of the death of Osiris
# 1         Shari Davis  What if you could help decide how the governme...
# 2    Nita Mosby Tyler        Want a more just world? Be an unlikely ally
# 3        Susan Lupack           The race to decode a mysterious language
# 4       Ariel Waldman  The colorful critter world of microbes in Anta...
# 5          Thomas Abt  Why violence clusters in cities — and how to r...
# 6     Steven Anderson                        What makes volcanoes erupt?
# 7  Christina Agapakis      What happens when biology becomes technology?
# 8     Ahmad M. Hasnah  Rethinking education and celebrating the Arabi...
# 9        Rod Phillips  What happened when the United States tried to ...
#
#   posted_date duration                                               Link  \
# 0    Jul 2020     3:56  https://www.ted.com/talks/alex_gendler_the_egy...
# ...

# %%
df1=pd.read_excel('datasets/football_worldcup.xlsx')
df1
# Out:
#    Year       Country   Winner    Runner-Up  GoalsScored  MatchesPlayed
# 0  1990         Italy  Germany    Argentina          115             52
# 1  1994           USA   Brazil        Italy          141             52
# 2  1998        France   France       Brazil          171             64
# 3  2002         Japan   Brazil      Germany          161             64
# 4  2006       Germany    Italy       France          147             64
# 5  2010  South Africa    Spain  Netherlands          145             64
# 6  2014        Brazil  Germany    Argentina          171             64

# %%
df1.shape
# Out:
# (7, 6)

# %%
df1.size
# Out:
# 42

# %%
df1.head()
# Out:
#    Year  Country   Winner  Runner-Up  GoalsScored  MatchesPlayed
# 0  1990    Italy  Germany  Argentina          115             52
# 1  1994      USA   Brazil      Italy          141             52
# 2  1998   France   France     Brazil          171             64
# 3  2002    Japan   Brazil    Germany          161             64
# 4  2006  Germany    Italy     France          147             64

# %%
df[1:4]
# Out:
#        speaker_name                                              title  \
# 1       Shari Davis  What if you could help decide how the governme...
# 2  Nita Mosby Tyler        Want a more just world? Be an unlikely ally
# 3      Susan Lupack           The race to decode a mysterious language
#
#   posted_date duration                                               Link  \
# 1    Jul 2020    10:28  https://www.ted.com/talks/shari_davis_what_if_...
# 2    Jul 2020    10:15  https://www.ted.com/talks/nita_mosby_tyler_wan...
# 3    Jul 2020     4:24  https://www.ted.com/talks/susan_lupack_the_rac...
#
#                                        about_speaker  \
# 1  As a leader of the Participatory Budgeting Pro...
# 2  Nita Mosby Tyler specializes in the developmen...
# 3                                                NaN
#
#                                           about_talk    views  \
# 1  What if you could help decide how the governme...  425,688
# ...

# %%
df.columns
# Out:
# Index(['speaker_name', 'title', 'posted_date', 'duration', 'Link',
#        'about_speaker', 'about_talk', 'views', 'tags'],
#       dtype='object')

# %%
df.views   #views in object format
# Out:
# 0         208,703
# 1         425,688
# 2         460,269
# 3         350,202
# 4         333,482
#           ...
# 2155    1,081,901
# 2156    1,914,256
# 2157    2,504,886
# 2158    1,104,616
# 2159    4,097,024
# Name: views, Length: 2160, dtype: object

# %%
df['views']
# Out:
# 0         208,703
# 1         425,688
# 2         460,269
# 3         350,202
# 4         333,482
#           ...
# 2155    1,081,901
# 2156    1,914,256
# 2157    2,504,886
# 2158    1,104,616
# 2159    4,097,024
# Name: views, Length: 2160, dtype: object

# %%
#change object format to another datatypes....

# %%
df
# Out:
#                            speaker_name  \
# 0                          Alex Gendler
# 1                           Shari Davis
# 2                      Nita Mosby Tyler
# 3                          Susan Lupack
# 4                         Ariel Waldman
# ...                                 ...
# 2155                       Nancy Frates
# 2156                      Will Marshall
# 2157                        David Grady
# 2158  Vincent Moon and Naná Vasconcelos
# 2159                       Alex Gendler
#
#                                                   title posted_date duration  \
# 0              The Egyptian myth of the death of Osiris    Jul 2020     3:56
# 1     What if you could help decide how the governme...    Jul 2020    10:28
# 2           Want a more just world? Be an unlikely ally    Jul 2020    10:15
# 3              The race to decode a mysterious language    Jul 2020     4:24
# 4     The colorful critter world of microbes in Anta...    Jul 2020     5:56
# ...

# %%
df['views'][8]='0'
df.views
# Out:
# 0         208,703
# 1         425,688
# 2         460,269
# 3         350,202
# 4         333,482
#           ...
# 2155    1,081,901
# 2156    1,914,256
# 2157    2,504,886
# 2158    1,104,616
# 2159    4,097,024
# Name: views, Length: 2160, dtype: object

# %%
#change object format to another datatypes....

# %%
def replace_comma(n):
    num=n.replace(",","")
    return num

# %%
df['views']=df['views'].apply(replace_comma)
df['views']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df['views']=df['views'].apply(replace_comma)
#       2 df['views']
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# ...

# %%
df['views']=df['views'].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "208,703"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df['views']=df['views'].apply(pd.to_numeric)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# ...

# %%
movie={'rating':[9.3,9.2,9.1,9.0,8.9,8.9,8.9,8.9],
      'title':['the god','msd','poc','real steel','dark knight','schindler','fight club','kgf'],
      'genere':['crime','guidj','hde','ueu','snd','nin','sok','bwok']}
df2=pd.DataFrame(movie)
df2
# Out:
#    rating        title genere
# 0     9.3      the god  crime
# 1     9.2          msd  guidj
# 2     9.1          poc    hde
# 3     9.0   real steel    ueu
# 4     8.9  dark knight    snd
# 5     8.9    schindler    nin
# 6     8.9   fight club    sok
# 7     8.9          kgf   bwok

# %%
df2.loc[3]=[9,'jk','frict']

# %%
df2
# Out:
#    rating        title genere
# 0     9.3      the god  crime
# 1     9.2          msd  guidj
# 2     9.1          poc    hde
# 3     9.0           jk  frict
# 4     8.9  dark knight    snd
# 5     8.9    schindler    nin
# 6     8.9   fight club    sok
# 7     8.9          kgf   bwok

# %%
df2=df2.drop(df2.index[[3,6]])
df2
# Out:
#    rating        title genere
# 0     9.3      the god  crime
# 1     9.2          msd  guidj
# 2     9.1          poc    hde
# 4     8.9  dark knight    snd
# 5     8.9    schindler    nin
# 7     8.9          kgf   bwok

# %%
#slicing and indexing

# %%
bike=pd.read_csv('datasets/201306-citibike-tripdata.csv')

# %%
bike
# Out:
#         tripduration            starttime             stoptime  \
# 0                695  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1                693  2013-06-01 00:00:08  2013-06-01 00:11:41
# 2               2059  2013-06-01 00:00:44  2013-06-01 00:35:03
# 3                123  2013-06-01 00:01:04  2013-06-01 00:03:07
# 4               1521  2013-06-01 00:01:22  2013-06-01 00:26:43
# ...              ...                  ...                  ...
# 577698           925  2013-06-30 23:59:27  2013-07-01 00:14:52
# 577699           279  2013-06-30 23:59:36  2013-07-01 00:04:15
# 577700           161  2013-06-30 23:59:33  2013-07-01 00:02:14
# 577701           909  2013-06-30 23:59:47  2013-07-01 00:14:56
# 577702           634  2013-07-01 00:00:00  2013-07-01 00:10:34
#
#         start station id      start station name  start station latitude  \
# 0                    444      Broadway & W 24 St               40.742354
# ...

# %%
bike.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           695  2013-06-01 00:00:01  2013-06-01 00:11:36               444
# 1           693  2013-06-01 00:00:08  2013-06-01 00:11:41               444
# 2          2059  2013-06-01 00:00:44  2013-06-01 00:35:03               406
# 3           123  2013-06-01 00:01:04  2013-06-01 00:03:07               475
# 4          1521  2013-06-01 00:01:22  2013-06-01 00:26:43              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
# ...

# %%
bike[['start station name','end station name']].head()
# Out:
#        start station name        end station name
# 0      Broadway & W 24 St         9 Ave & W 18 St
# 1      Broadway & W 24 St         9 Ave & W 18 St
# 2  Hicks St & Montague St  Hicks St & Montague St
# 3     E 15 St & Irving Pl         Washington Park
# 4   Little West St & 1 Pl     State St & Smith St

# %%
bike.at[1,'start station id']
# Out:
# 444

# %%
bike.at[1,'start station id']=34

# %%
bike
# Out:
#         tripduration            starttime             stoptime  \
# 0                695  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1                693  2013-06-01 00:00:08  2013-06-01 00:11:41
# 2               2059  2013-06-01 00:00:44  2013-06-01 00:35:03
# 3                123  2013-06-01 00:01:04  2013-06-01 00:03:07
# 4               1521  2013-06-01 00:01:22  2013-06-01 00:26:43
# ...              ...                  ...                  ...
# 577698           925  2013-06-30 23:59:27  2013-07-01 00:14:52
# 577699           279  2013-06-30 23:59:36  2013-07-01 00:04:15
# 577700           161  2013-06-30 23:59:33  2013-07-01 00:02:14
# 577701           909  2013-06-30 23:59:47  2013-07-01 00:14:56
# 577702           634  2013-07-01 00:00:00  2013-07-01 00:10:34
#
#         start station id      start station name  start station latitude  \
# 0                    444      Broadway & W 24 St               40.742354
# ...

# %%
new_bike.index=['bike'+str(i) for(i) in range(1,11)]
new_bike
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 new_bike.index=['bike'+str(i) for(i) in range(1,11)]
#       2 new_bike
#
# NameError: name 'new_bike' is not defined

# %%
bike
# Out:
#         tripduration            starttime             stoptime  \
# 0                695  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1                693  2013-06-01 00:00:08  2013-06-01 00:11:41
# 2               2059  2013-06-01 00:00:44  2013-06-01 00:35:03
# 3                123  2013-06-01 00:01:04  2013-06-01 00:03:07
# 4               1521  2013-06-01 00:01:22  2013-06-01 00:26:43
# ...              ...                  ...                  ...
# 577698           925  2013-06-30 23:59:27  2013-07-01 00:14:52
# 577699           279  2013-06-30 23:59:36  2013-07-01 00:04:15
# 577700           161  2013-06-30 23:59:33  2013-07-01 00:02:14
# 577701           909  2013-06-30 23:59:47  2013-07-01 00:14:56
# 577702           634  2013-07-01 00:00:00  2013-07-01 00:10:34
#
#         start station id      start station name  start station latitude  \
# 0                    444      Broadway & W 24 St               40.742354
# ...

# %%
bike.iloc[3:7]

# %%
#concatenation

# %%
students = pd.DataFrame({'id_number':[201,202,203,204,205], 
                         "Name": ['Smirti', 'Rohit', "Dinesh", "Rishab","Jasprit"],

                        "age": [24,34,36,30,31],

                        "Gender":['F', 'M', 'M', 'M','M']})

# %%
students
# Out:
#    id_number     Name  age Gender
# 0        201   Smirti   24      F
# 1        202    Rohit   34      M
# 2        203   Dinesh   36      M
# 3        204   Rishab   30      M
# 4        205  Jasprit   31      M

# %%
 Professors= pd.DataFrame({ 'Prof_name': ['Ashish Nehra', 'LAsith MAlinga', 'Robin Singh', 'Rahul Dravid', 'Sachin Tendulkar'], 'id_number':

[201,203,208,205,204],

'Department': ['Bowling', 'Bowling', 'Fielding', 'Batting', 'Batting']

})

# %%
Professors
# Out:
#           Prof_name  id_number Department
# 0      Ashish Nehra        201    Bowling
# 1    LAsith MAlinga        203    Bowling
# 2       Robin Singh        208   Fielding
# 3      Rahul Dravid        205    Batting
# 4  Sachin Tendulkar        204    Batting

# %%
movie
# Out:
# {'rating': [9.3, 9.2, 9.1, 9.0, 8.9, 8.9, 8.9, 8.9],
#  'title': ['the god',
#   'msd',
#   'poc',
#   'real steel',
#   'dark knight',
#   'schindler',
#   'fight club',
#   'kgf'],
#  'genere': ['crime', 'guidj', 'hde', 'ueu', 'snd', 'nin', 'sok', 'bwok']}

# %%
df2
# Out:
#    rating        title genere
# 0     9.3      the god  crime
# 1     9.2          msd  guidj
# 2     9.1          poc    hde
# 4     8.9  dark knight    snd
# 5     8.9    schindler    nin
# 7     8.9          kgf   bwok

# %%
for i in df2.itertuples():
    print(i)
# Out:
# Pandas(Index=0, rating=9.3, title='the god', genere='crime')
# Pandas(Index=1, rating=9.2, title='msd', genere='guidj')
# Pandas(Index=2, rating=9.1, title='poc', genere='hde')
# Pandas(Index=4, rating=8.9, title='dark knight', genere='snd')
# Pandas(Index=5, rating=8.9, title='schindler', genere='nin')
# Pandas(Index=7, rating=8.9, title='kgf', genere='bwok')

# %%
for i in df2.iterrows():
    print(i)
# Out:
# (0, rating        9.3
# title     the god
# genere      crime
# Name: 0, dtype: object)
# (1, rating      9.2
# title       msd
# genere    guidj
# Name: 1, dtype: object)
# (2, rating    9.1
# title     poc
# genere    hde
# Name: 2, dtype: object)
# (4, rating            8.9
# title     dark knight
# genere            snd
# Name: 4, dtype: object)
# (5, rating          8.9
# title     schindler
# genere          nin
# Name: 5, dtype: object)
# (7, rating     8.9
# title      kgf
# genere    bwok
# Name: 7, dtype: object)

# %%
for ind,ser in df2.iterrows():
    print(ind)
    print(ser)
# Out:
# 0
# rating        9.3
# title     the god
# genere      crime
# Name: 0, dtype: object
# 1
# rating      9.2
# title       msd
# genere    guidj
# Name: 1, dtype: object
# 2
# rating    9.1
# title     poc
# genere    hde
# Name: 2, dtype: object
# 4
# rating            8.9
# title     dark knight
# genere            snd
# Name: 4, dtype: object
# 5
# rating          8.9
# title     schindler
# genere          nin
# Name: 5, dtype: object
# 7
# rating     8.9
# title      kgf
# genere    bwok
# Name: 7, dtype: object

# %%
for col,ser in df2.iteritems():
    print(col) 
    print(ser)
# Out:
# rating
# 0    9.3
# 1    9.2
# 2    9.1
# 4    8.9
# 5    8.9
# 7    8.9
# Name: rating, dtype: float64
# title
# 0        the god
# 1            msd
# 2            poc
# 4    dark knight
# 5      schindler
# 7            kgf
# Name: title, dtype: object
# genere
# 0    crime
# 1    guidj
# 2      hde
# 4      snd
# 5      nin
# 7     bwok
# Name: genere, dtype: object
