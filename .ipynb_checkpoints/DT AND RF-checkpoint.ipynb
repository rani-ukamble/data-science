# %%
import pandas as pd 
import numpy as np 
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve,auc
from sklearn import svm

import matplotlib.pyplot as plt
from six import StringIO
from IPython.display import Image
import pydotplus
from sklearn.tree import export_graphviz
import seaborn as sns

# %%
df=pd.read_csv('datasets/bank-full.csv')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 0        unknown    5   may       261         1     -1         0  unknown
# 1        unknown    5   may       151         1     -1         0  unknown
# 2        unknown    5   may        76         1     -1         0  unknown
# 3        unknown    5   may        92         1     -1         0  unknown
# 4        unknown    5   may       198         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 45206   cellular   17   nov       977         3     -1         0  unknown
# 45207   cellular   17   nov       456         2     -1         0  unknown
# 45208   cellular   17   nov      1127         5    184         3  success
# 45209  telephone   17   nov       508         4     -1         0  unknown
# 45210   cellular   17   nov       361         2    188        11    other
#
#       Target
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
# ...      ...
# 45206    yes
# 45207    yes
# 45208    yes
# 45209     no
# 45210     no
#
# [45211 rows x 17 columns]

# %%
temp=df.columns.values[0]
temp
# Out:
# 'age'

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
#check not null values

df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# Target       0
# dtype: int64

# %%
corrmat=df.corr()
k=10 #no. of variable for heatmap

cols=corrmat.nlargest(k,'age')['age'].index
cm=np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)

# %%
plt.figure(figsize=(10,6))
df.balance.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['balance'].describe()
# Out:
# count     45211.000000
# mean       1362.272058
# std        3044.765829
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %%
df.drop(df[df['balance']>1428].index, axis=0, inplace=True)

# %%
df.drop(df[df['balance']<72].index, axis=0, inplace=True)

# %%
df
# Out:
#        age          job   marital  education default  balance housing loan  \
# 5       35   management   married   tertiary      no      231     yes   no
# 6       28   management    single   tertiary      no      447     yes  yes
# 8       58      retired   married    primary      no      121     yes   no
# 9       43   technician    single  secondary      no      593     yes   no
# 10      41       admin.  divorced  secondary      no      270     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 45202   34       admin.    single  secondary      no      557      no   no
# 45203   23      student    single   tertiary      no      113      no   no
# 45205   25   technician    single  secondary      no      505      no  yes
# 45206   51   technician   married   tertiary      no      825      no   no
# 45209   57  blue-collar   married  secondary      no      668      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 5        unknown    5   may       139         1     -1         0  unknown
# 6        unknown    5   may       217         1     -1         0  unknown
# 8        unknown    5   may        50         1     -1         0  unknown
# 9        unknown    5   may        55         1     -1         0  unknown
# 10       unknown    5   may       222         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 45202   cellular   17   nov       224         1     -1         0  unknown
# 45203   cellular   17   nov       266         1     -1         0  unknown
# 45205   cellular   17   nov       386         2     -1         0  unknown
# 45206   cellular   17   nov       977         3     -1         0  unknown
# 45209  telephone   17   nov       508         4     -1         0  unknown
#
#       Target
# 5         no
# 6         no
# 8         no
# 9         no
# 10        no
# ...      ...
# 45202    yes
# 45203    yes
# 45205    yes
# 45206    yes
# 45209     no
#
# [22636 rows x 17 columns]

# %%
df.shape
# Out:
# (22636, 17)

# %%
plt.figure(figsize=(10,6))
df.age.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['age'].describe()
# Out:
# count    22636.000000
# mean        40.264888
# std         10.418085
# min         18.000000
# 25%         32.000000
# 50%         38.000000
# 75%         47.000000
# max         94.000000
# Name: age, dtype: float64

# %%
df.drop(df[df['age']<33].index, axis=0, inplace=True)

# %%
df.drop(df[df['age']>48].index, axis=0, inplace=True)

# %%
df
# Out:
#        age         job   marital  education default  balance housing loan  \
# 5       35  management   married   tertiary      no      231     yes   no
# 9       43  technician    single  secondary      no      593     yes   no
# 10      41      admin.  divorced  secondary      no      270     yes   no
# 26      39  management    single   tertiary      no      255     yes   no
# 29      36  technician    single  secondary      no      265     yes  yes
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 45179   34  technician   married  secondary      no     1026      no   no
# 45182   34  technician   married  secondary      no      133      no   no
# 45198   37  management   married   tertiary      no     1428      no   no
# 45200   38  technician   married  secondary      no      557     yes   no
# 45202   34      admin.    single  secondary      no      557      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 5       unknown    5   may       139         1     -1         0  unknown
# 9       unknown    5   may        55         1     -1         0  unknown
# 10      unknown    5   may       222         1     -1         0  unknown
# 26      unknown    5   may       296         1     -1         0  unknown
# 29      unknown    5   may       348         1     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 45179  cellular   12   nov       319         1    100         6  failure
# 45182  cellular   15   nov       401         2    187         5  success
# 45198  cellular   16   nov       333         2     -1         0  unknown
# 45200  cellular   16   nov      1556         4     -1         0  unknown
# 45202  cellular   17   nov       224         1     -1         0  unknown
#
#       Target
# 5         no
# 9         no
# 10        no
# 26        no
# 29        no
# ...      ...
# 45179     no
# 45182    yes
# 45198     no
# 45200    yes
# 45202    yes
#
# [11508 rows x 17 columns]

# %%
plt.figure(figsize=(10,6))
df.day.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['day'].describe()
# Out:
# count    11508.000000
# mean        15.347671
# std          8.255932
# min          1.000000
# 25%          8.000000
# 50%         15.000000
# 75%         21.000000
# max         31.000000
# Name: day, dtype: float64

# %%
df.drop(df[df['day']<23].index, axis=0, inplace=True)

# %%
df.drop(df[df['day']>29].index, axis=0, inplace=True)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 5212    35   blue-collar    single  secondary      no      773     yes   no
# 5215    36   blue-collar    single  secondary      no      690     yes   no
# 5217    39   blue-collar   married  secondary      no      439     yes   no
# 5221    37    technician    single  secondary      no      363     yes   no
# 5223    33    technician    single  secondary      no      486     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45108   36    technician   married   tertiary      no      844     yes  yes
# 45114   36    technician    single  secondary      no      204     yes   no
# 45119   47        admin.   married  secondary      no     1210      no   no
# 45122   40  entrepreneur    single   tertiary      no      262     yes  yes
# 45125   40    management  divorced   tertiary      no      858      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 5212    unknown   23   may       136         2     -1         0  unknown
# 5215    unknown   23   may        86         2     -1         0  unknown
# 5217    unknown   23   may       214         3     -1         0  unknown
# 5221    unknown   23   may       110         3     -1         0  unknown
# 5223    unknown   23   may       363         2     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 45108  cellular   25   oct       129         1     -1         0  unknown
# 45114  cellular   26   oct       196         1    144         8    other
# 45119  cellular   26   oct       604         1     91         4  failure
# 45122   unknown   26   oct        17         1     -1         0  unknown
# 45125  cellular   26   oct       202         2     -1         0  unknown
#
#       Target
# 5212      no
# 5215      no
# 5217      no
# 5221      no
# 5223      no
# ...      ...
# 45108     no
# 45114     no
# 45119    yes
# 45122     no
# 45125    yes
#
# [1822 rows x 17 columns]

# %%
plt.figure(figsize=(10,6))
df.day.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['duration'].describe()
# Out:
# count    1822.000000
# mean      231.594951
# std       236.329700
# min         6.000000
# 25%        93.000000
# 50%       160.000000
# 75%       282.000000
# max      3785.000000
# Name: duration, dtype: float64

# %%
df.drop(df[df['duration']<89].index, axis=0, inplace=True)

# %%
df.drop(df[df['duration']>312].index, axis=0, inplace=True)

# %%
df
# Out:
#        age          job   marital  education default  balance housing loan  \
# 5212    35  blue-collar    single  secondary      no      773     yes   no
# 5217    39  blue-collar   married  secondary      no      439     yes   no
# 5221    37   technician    single  secondary      no      363     yes   no
# 5224    33   technician    single   tertiary      no      594     yes  yes
# 5227    33  blue-collar    single  secondary      no      372     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 44909   39   technician   married   tertiary      no      386      no   no
# 45100   34  blue-collar   married  secondary      no      152      no   no
# 45108   36   technician   married   tertiary      no      844     yes  yes
# 45114   36   technician    single  secondary      no      204     yes   no
# 45125   40   management  divorced   tertiary      no      858      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 5212    unknown   23   may       136         2     -1         0  unknown
# 5217    unknown   23   may       214         3     -1         0  unknown
# 5221    unknown   23   may       110         3     -1         0  unknown
# 5224    unknown   23   may       149         1     -1         0  unknown
# 5227    unknown   23   may        92         1     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 44909  cellular   29   sep       201         2     -1         0  unknown
# 45100  cellular   25   oct       275         1     -1         0  unknown
# 45108  cellular   25   oct       129         1     -1         0  unknown
# 45114  cellular   26   oct       196         1    144         8    other
# 45125  cellular   26   oct       202         2     -1         0  unknown
#
#       Target
# 5212      no
# 5217      no
# 5221      no
# 5224      no
# 5227      no
# ...      ...
# 44909     no
# 45100     no
# 45108     no
# 45114     no
# 45125    yes
#
# [999 rows x 17 columns]

# %%
plt.figure(figsize=(10,6))
df.duration.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['campaign'].describe()
# Out:
# count    999.000000
# mean       3.231231
# std        3.485094
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max       50.000000
# Name: campaign, dtype: float64

# %%
df.drop(df[df['campaign']>3].index, axis=0, inplace=True)

# %%
df
# Out:
#        age          job   marital  education default  balance housing loan  \
# 5212    35  blue-collar    single  secondary      no      773     yes   no
# 5217    39  blue-collar   married  secondary      no      439     yes   no
# 5221    37   technician    single  secondary      no      363     yes   no
# 5224    33   technician    single   tertiary      no      594     yes  yes
# 5227    33  blue-collar    single  secondary      no      372     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 44909   39   technician   married   tertiary      no      386      no   no
# 45100   34  blue-collar   married  secondary      no      152      no   no
# 45108   36   technician   married   tertiary      no      844     yes  yes
# 45114   36   technician    single  secondary      no      204     yes   no
# 45125   40   management  divorced   tertiary      no      858      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 5212    unknown   23   may       136         2     -1         0  unknown
# 5217    unknown   23   may       214         3     -1         0  unknown
# 5221    unknown   23   may       110         3     -1         0  unknown
# 5224    unknown   23   may       149         1     -1         0  unknown
# 5227    unknown   23   may        92         1     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 44909  cellular   29   sep       201         2     -1         0  unknown
# 45100  cellular   25   oct       275         1     -1         0  unknown
# 45108  cellular   25   oct       129         1     -1         0  unknown
# 45114  cellular   26   oct       196         1    144         8    other
# 45125  cellular   26   oct       202         2     -1         0  unknown
#
#       Target
# 5212      no
# 5217      no
# 5221      no
# 5224      no
# 5227      no
# ...      ...
# 44909     no
# 45100     no
# 45108     no
# 45114     no
# 45125    yes
#
# [714 rows x 17 columns]

# %%
plt.figure(figsize=(10,6))
df.pdays.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['pdays'].describe()
# Out:
# count    714.000000
# mean      31.592437
# std       85.055237
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%       -1.000000
# max      555.000000
# Name: pdays, dtype: float64

# %%
plt.figure(figsize=(10,6))
df.previous.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['previous'].describe()
# Out:
# count    714.000000
# mean       0.474790
# std        1.475392
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       13.000000
# Name: previous, dtype: float64

# %%
df.drop(df[df['previous']>0].index, axis=0, inplace=True)

# %%
df
# Out:
#        age          job   marital  education default  balance housing loan  \
# 5212    35  blue-collar    single  secondary      no      773     yes   no
# 5217    39  blue-collar   married  secondary      no      439     yes   no
# 5221    37   technician    single  secondary      no      363     yes   no
# 5224    33   technician    single   tertiary      no      594     yes  yes
# 5227    33  blue-collar    single  secondary      no      372     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 44880   38   management   married   tertiary      no      845      no   no
# 44909   39   technician   married   tertiary      no      386      no   no
# 45100   34  blue-collar   married  secondary      no      152      no   no
# 45108   36   technician   married   tertiary      no      844     yes  yes
# 45125   40   management  divorced   tertiary      no      858      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 5212    unknown   23   may       136         2     -1         0  unknown
# 5217    unknown   23   may       214         3     -1         0  unknown
# 5221    unknown   23   may       110         3     -1         0  unknown
# 5224    unknown   23   may       149         1     -1         0  unknown
# 5227    unknown   23   may        92         1     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 44880  cellular   23   sep       134         1     -1         0  unknown
# 44909  cellular   29   sep       201         2     -1         0  unknown
# 45100  cellular   25   oct       275         1     -1         0  unknown
# 45108  cellular   25   oct       129         1     -1         0  unknown
# 45125  cellular   26   oct       202         2     -1         0  unknown
#
#       Target
# 5212      no
# 5217      no
# 5221      no
# 5224      no
# 5227      no
# ...      ...
# 44880     no
# 44909     no
# 45100     no
# 45108     no
# 45125    yes
#
# [605 rows x 17 columns]

# %%
def preprocessor(df):
    res_df=df.copy()
    le=preprocessing.LabelEncoder()
    res_df['job']=le.fit_transform(res_df['job'])
    res_df['marital']=le.fit_transform(res_df['marital'])
    res_df['education']=le.fit_transform(res_df['education'])
    res_df['default']=le.fit_transform(res_df['default'])
    res_df['housing']=le.fit_transform(res_df['housing'])
    res_df['loan']=le.fit_transform(res_df['loan'])
    res_df['contact']=le.fit_transform(res_df['contact'])
    res_df['month']=le.fit_transform(res_df['month'])
    res_df['poutcome']=le.fit_transform(res_df['job'])
    res_df['Target']=le.fit_transform(res_df['job'])
    return res_df

# %%
encoded_df=preprocessor(df)
encoded_df.head()
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 5212   35    1        2          1        0      773        1     0        2
# 5217   39    1        1          1        0      439        1     0        2
# 5221   37    9        2          1        0      363        1     0        2
# 5224   33    9        2          2        0      594        1     1        2
# 5227   33    1        2          1        0      372        1     0        2
#
#       day  month  duration  campaign  pdays  previous  poutcome  Target
# 5212   23      8       136         2     -1         0         1       1
# 5217   23      8       214         3     -1         0         1       1
# 5221   23      8       110         3     -1         0         9       9
# 5224   23      8       149         1     -1         0         9       9
# 5227   23      8        92         1     -1         0         1       1

# %%
x=encoded_df.drop('Target',axis=1).values
y=encoded_df['Target'].values

# %%
#split data into train and test database

x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=0.2)

# %%
#Decision tree with depth 2

model_df_2=DecisionTreeClassifier(random_state=1,max_depth=2)

model_df_2.fit(x_train,y_train)

model_df_2_score_train=model_df_2.score(x_train,y_train)

model_df_2_score_test=model_df_2.score(x_test,y_test)

print('Training score',model_df_2_score_train)

print('Testing score',model_df_2_score_test)
# Out:
# Training score 0.7747933884297521
# Testing score 0.7768595041322314

# %%
#Decision tree with depth 4

model_df_4=DecisionTreeClassifier(random_state=1,max_depth=4)

model_df_4.fit(x_train,y_train)

model_df_4_score_train=model_df_4.score(x_train,y_train)

model_df_4_score_test=model_df_4.score(x_test,y_test)

print('Training score',model_df_4_score_train)

print('Testing score',model_df_4_score_test)
# Out:
# Training score 0.9421487603305785
# Testing score 0.9173553719008265

# %%
#Decision tree with depth 6

model_df_6=DecisionTreeClassifier(random_state=1,max_depth=6)

model_df_6.fit(x_train,y_train)

model_df_6_score_train=model_df_6.score(x_train,y_train)

model_df_6_score_test=model_df_6.score(x_test,y_test)

print('Training score',model_df_6_score_train)

print('Testing score',model_df_6_score_test)
# Out:
# Training score 1.0
# Testing score 0.9917355371900827

# %%
plt.figure(figsize=(10,20))
dot_data=StringIO()
export_graphviz(model_df_6,out_file=dot_data,filled=True,rounded=True, special_characters=True)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
plt.figure(figsize=(10,20))
dot_data=StringIO()
export_graphviz(model_dt,out_file=dot_data,filled=True,rounded=True, special_characters=True)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 3>()
#       1 plt.figure(figsize=(10,20))
#       2 dot_data=StringIO()
# ----> 3 export_graphviz(model_dt,out_file=dot_data,filled=True,rounded=True, special_characters=True)
#       4 graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
#       5 Image(graph.create_png())
#
# NameError: name 'model_dt' is not defined
