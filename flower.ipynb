# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('datasets/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
sns.lmplot(x='SepalLengthCm',y='SepalWidthCm',data=df,col='Species')

# %%
sns.lmplot(x='PetalLengthCm',y='PetalWidthCm',data=df,col='Species')

# %%
sns.lmplot(x='PetalLengthCm',y='PetalWidthCm',data=df,hue='Species')

# %%
sns.lmplot(x='SepalLengthCm',y='SepalWidthCm',data=df,hue='Species')

# %%
plt.subplots(figsize=(15,8))
sns.boxplot(x='Species',y='SepalLengthCm',data=df)
plt.show()

# %%
plt.subplots(figsize=(15,8))
sns.boxplot(x='Species',y='SepalWidthCm',data=df)
plt.show()

# %%
plt.subplots(figsize=(15,8))
sns.boxplot(x='Species',y='PetalLengthCm',data=df)
plt.show()

# %%
plt.subplots(figsize=(15,8))
sns.boxplot(x='Species',y='PetalWidthCm',data=df)
plt.show()

# %%
sns.catplot(x='Species',y='SepalLengthCm',data=df,kind='bar')

# %%
sns.catplot(x='Species',y='SepalWidthCm',data=df,kind='bar')

# %%
sns.catplot(x='Species',y='PetalLengthCm',data=df,kind='bar')

# %%
sns.catplot(x='Species',y='PetalWidthCm',data=df,kind='bar')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
sum_df=df['SepalLengthCm'].sum()
mean_df=df['SepalLengthCm'].mean()
median_df=df['SepalLengthCm'].median()

# %%
sum_df
# Out:
# 876.5

# %%
mean_df
# Out:
# 5.843333333333335

# %%
median_df
# Out:
# 5.8

# %%
df.corr(method='pearson')
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# #Multivariate Analysis

# %%
sns.pairplot(df.drop(['Id'],axis=1),hue='Species')

# %% [markdown]
# #Conclusion

# %% [markdown]
# #Species setosa has less features than species versicolor and virginica except the sepalwidth. #Species versicolor has average features. #Species virginica has high features. #Species setosa has high sepalwidth species versicolor has average and virginica has less sepalwidth.
#
# #Species virginica has some outliers in SepalLengthCm and Sepalwidth. #Species setosa and versicolor has some outliers in PetalLengthCm. #Species setosa has some outliers in PetalWidthCm
